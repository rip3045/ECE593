# %%
import numpy as np
from scipy.integrate import odeint
import math
import dubins

# %%
### calculation of the dubins path, I did the hard stuff by hand

# %%
from IPython import display
display.Image("./desmos_calc.png")

# %%
import cmath

a1 = (50-(15*cmath.sqrt(10)))/cmath.sqrt(10)

a = 10
b = 10-6*a1
c = a1^2

# calculate the discriminant
d = (b**2) - (4*a*c)

# find two solutions
sol1 = (-b-cmath.sqrt(d))/(2*a)
sol2 = (-b+cmath.sqrt(d))/(2*a)

print('The solution are {0} and {1}'.format(sol1,sol2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-57827a92e3f5> in <module>
#       5 a = 10
#       6 b = 10-6*a1
# ----> 7 c = a1^2
#       8
#       9 # calculate the discriminant
#
# TypeError: unsupported operand type(s) for ^: 'complex' and 'int'

# %%
### the integration for the dubins path, s means straight, c means curve
## the equation for the tangent line is y = -3x+50/sqrt(10), I did this part by hand
length = 1.5*math.pi*5+2*math.sqrt(10)
num_pts = 50000
del_d = length/num_pts
c_to_s_pt = []
s_to_c_pt = []
init_state = [0, -15, 90]
init_state = np.array([0])
# Out:
# 0.0005977300044452042

# %%
for i in length
